# %%
import numpy as np
import scipy.stats as st
import pandas as pd
import sys

# %%
sys.path.append('/Users/chrismorrow/repos/sci_analysis')

# %%
import sci_analysis as a

# %%
np.random.seed(987654321)
input_array = st.norm.rvs(size=200)
a.analyze(input_array)
# Out:
#
# Statistics
# ----------
#
# Count     =  200
# Mean      =  0.0280
# Std Dev   =  1.0721
# Std Error =  0.0758
# Skewness  =  0.0749
# Kurtosis  = -0.4303
# Maximum   =  3.1400
# 75%       =  0.7772
# 50%       =  0.0371
# 25%       = -0.7605
# Minimum   = -2.4718
# IQR       =  1.5377
# Range     =  5.6117
#
#
# Shapiro-Wilk test for normality
# -------------------------------
#
# W value =  0.9947
# p value =  0.7092
#
# H0: Data is normally distributed

# %%
np.random.seed(987654321)
input_array = st.norm.rvs(size=200)
a.analyze(input_array, cdf=True, fit=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-5e7de9b3c924> in <module>()
#       1 np.random.seed(987654321)
#       2 input_array = st.norm.rvs(size=200)
# ----> 3 a.analyze(input_array, cdf=True, fit=True)
#
# /Users/chrismorrow/repos/sci_analysis/sci_analysis/analysis/analysis.py in analyze(*data, **kwargs)
#     999             fit = NormTest(xdata, alpha=alpha, display=False)
#    1000             tested.append('NormTest')
# -> 1001         GraphHisto(xdata, mean="{: .4f}".format(stats.mean), std_dev="{: .4f}".format(stats.std_dev), **kwargs)
#    1002         print(stats)
#    1003         print(fit)
#
# /Users/chrismorrow/repos/sci_analysis/sci_analysis/graphs/graph.py in __init__(self, data, **kwargs)
#     180             name = kwargs['xname']
#     181
# --> 182         super(GraphHisto, self).__init__(data, xname=name, yname=yname)
#     183         # if GraphPreferences.Plot.boxplot != GraphPreferences.Plot.defaults[0]:
#     184         #    _box_plot = GraphPreferences.Plot.boxplot
#
# /Users/chrismorrow/repos/sci_analysis/sci_analysis/graphs/graph.py in __init__(self, *args, **kwargs)
#      97                 data = data[0]
#      98             self._data = data
# ---> 99         self.draw()
#     100
#     101     @staticmethod
#
# /Users/chrismorrow/repos/sci_analysis/sci_analysis/graphs/graph.py in draw(self)
#     245         # Fit the distribution
#     246         if self._fit:
# --> 247             distro, distro_pdf, distro_cdf = self.fit_distro()
#     248         else:
#     249             distro, distro_pdf, distro_cdf = None, None, None
#
# /Users/chrismorrow/repos/sci_analysis/sci_analysis/graphs/graph.py in fit_distro(self)
#     194                                           globals(),
#     195                                           locals(),
# --> 196                                           [self._distribution], -1), self._distribution)
#     197         parms = distro_class.fit(self._data)
#     198         distro = linspace(distro_class.ppf(0.001, *parms), distro_class.ppf(0.999, *parms), 100)
#
# ValueError: level must be >= 0

# %%
np.random.seed(987654321)
input_array = st.weibull_min.rvs(1.7, size=500)
a.analyze(input_array, cdf=True, fit=True, distribution='weibull_min')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-c90e13e2aafe> in <module>()
#       1 np.random.seed(987654321)
#       2 input_array = st.weibull_min.rvs(1.7, size=500)
# ----> 3 a.analyze(input_array, cdf=True, fit=True, distribution='weibull_min')
#
# /Users/chrismorrow/repos/sci_analysis/sci_analysis/analysis/analysis.py in analyze(*data, **kwargs)
#     992                                               globals(),
#     993                                               locals(),
# --> 994                                               [distro], -1), distro)
#     995             parms = distro_class.fit(xdata)
#     996             fit = KSTest(xdata, distribution=distro, parms=parms, alpha=alpha, display=False)
#
# ValueError: level must be >= 0

# %%
source_path = "/Users/chrismorrow/Dropbox/Data/"
df = pd.read_csv(source_path + "/BodyFat.csv")

# %%
df.corr()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th
# R^2       =  0.8137
# Std Err   =  0.0264
# p value   =  0.0000
#
# HA: There is a significant relationship between predictor and response
#
#
# Spearman Correlation Coefficient
# --------------------------------
#
# r value =  0.8155
# p value =  0.0000
#
# HA: There is a significant relationship between predictor and response

# %%
a.analyze(df['ABDOMEN'], df['BODYFAT'], xname='Abdomen', yname='Bodyfat', boxplot_borders=True)
# Out:
#
# Linear Regression
# -----------------
#
# Count     =  252
# Slope     =  0.5849
# Intercept = -35.1966
# R^2       =  0.8137
# Std Err   =  0.0264
# p value   =  0.0000
#
# HA: There is a significant relationship between predictor and response
#
#
# Spearman Correlation Coefficient
# --------------------------------
#
# p value =  0.0000
# r value =  0.8155
#
# HA: There is a significant relationship between predictor and response

# %%
a.analyze(df['ABDOMEN'], df['BODYFAT'], xname='Abdomen', yname='Bodyfat', boxplot_borders=True, fit=False, 
          contours=True)
# Out:
#
# Linear Regression
# -----------------
#
# Count     =  252
# Slope     =  0.5849
# Intercept = -35.1966
# R^2       =  0.8137
# Std Err   =  0.0264
# p value   =  0.0000
#
# HA: There is a significant relationship between predictor and response
#
#
# Spearman Correlation Coefficient
# --------------------------------
#
# p value =  0.0000
# r value =  0.8155
#
# HA: There is a significant relationship between predictor and response

# %%
a.analyze(df['BODYFAT'], name='Bodyfat', fit=True)
# Out:
#
# Statistics
# ----------
#
# Count     =  252
# Mean      =  18.9385
# Std Dev   =  7.7509
# Std Error =  0.4883
# Skewness  =  0.1434
# Kurtosis  = -0.3245
# Maximum   =  45.1000
# 75%       =  24.6000
# 50%       =  19.0000
# 25%       =  12.8000
# Minimum   =  0.0000
# IQR       =  11.8000
# Range     =  45.1000
#
#
# Shapiro-Wilk test for normality
# -------------------------------
#
# W value =  0.9929
# p value =  0.2747
#
# H0: Data is normally distributed

# %%
a.analyze(df['AGE'], name='Age')
# Out:
#
# Statistics
# ----------
#
# Count     =  252
# Mean      =  44.8849
# Std Dev   =  12.6020
# Std Error =  0.7939
# Skewness  =  0.2818
# Kurtosis  = -0.4319
# Maximum   =  81.0000
# 75%       =  54.0000
# 50%       =  43.0000
# 25%       =  35.7500
# Minimum   =  22.0000
# IQR       =  18.2500
# Range     =  59.0000
#
#
# Shapiro-Wilk test for normality
# -------------------------------
#
# W value =  0.9795
# p value =  0.0010
#
# HA: Data is not normally distributed

# %%
df.groupby('Age_Range').mean()['BODYFAT']
# Out:
# Age_Range
# (20, 26]    15.105000
# (26, 33]    15.106897
# (33, 39]    17.815385
# (39, 45]    20.053968
# (45, 51]    19.044186
# (51, 57]    17.828125
# (57, 63]    22.242857
# (63, 69]    24.275000
# (69, 75]    24.425000
# (75, 81]    21.100000
# Name: BODYFAT, dtype: float64

# %%
df2 = df[df['HEIGHT'] > 60]
height = {name: group['HEIGHT'].values for name, group in df2[df2['Age_Range'] != '(75, 81]'].groupby('Age_Range')}
a.analyze(height)
# Out:
# Group Statistics
#
# Count         Mean          Std Dev       Min           Median        Max           Group
# --------------------------------------------------------------------------------------------------
# 43             70.4535       2.8000        64.0000       70.7500       75.0000      (45, 51]
# 14             68.8393       2.4369        65.7500       67.7500       73.2500      (57, 63]
# 16             68.8125       2.2922        65.7500       68.5000       72.7500      (63, 69]
# 8              68.7188       1.7031        66.0000       69.5000       70.5000      (69, 75]
# 29             70.5345       2.6201        64.7500       71.0000       76.0000      (26, 33]
# 62             70.6452       2.3195        65.5000       70.1250       76.0000      (39, 45]
# 32             70.1328       2.8575        64.0000       69.7500       77.7500      (51, 57]
# 26             70.2308       2.4412        65.5000       70.6250       74.5000      (33, 39]
# 20             71.9000       2.6462        66.2500       72.2500       77.5000      (20, 26]
#
#
# Bartlett Test
# -------------
#
# T value =  4.9101
# p value =  0.7671
#
# H0: Variances are equal
#
#
# Oneway ANOVA
# ------------
#
# f value =  2.8454
# p value =  0.0049
#
# HA: Group means are not matched

# %%
df2 = df[df['HEIGHT'] > 60]
groups = list()
height = list()
for name, group in df2[df2['Age_Range'] != '(75, 81]'].groupby('Age_Range'):
    groups.append(name)
    height.append(group['HEIGHT'].values)
a.analyze(height, groups=groups, categories='Age Group', name='Height', title='Height by Age Group')
# Out:
# Group Statistics
#
# Count         Mean          Std Dev       Min           Median        Max           Group
# --------------------------------------------------------------------------------------------------
# 43             70.4535       2.8000        64.0000       70.7500       75.0000      (45, 51]
# 14             68.8393       2.4369        65.7500       67.7500       73.2500      (57, 63]
# 16             68.8125       2.2922        65.7500       68.5000       72.7500      (63, 69]
# 8              68.7188       1.7031        66.0000       69.5000       70.5000      (69, 75]
# 29             70.5345       2.6201        64.7500       71.0000       76.0000      (26, 33]
# 62             70.6452       2.3195        65.5000       70.1250       76.0000      (39, 45]
# 32             70.1328       2.8575        64.0000       69.7500       77.7500      (51, 57]
# 26             70.2308       2.4412        65.5000       70.6250       74.5000      (33, 39]
# 20             71.9000       2.6462        66.2500       72.2500       77.5000      (20, 26]
#
#
# Bartlett Test
# -------------
#
# T value =  4.9101
# p value =  0.7671
#
# H0: Variances are equal
#
#
# Oneway ANOVA
# ------------
#
# f value =  2.8454
# p value =  0.0049
#
# HA: Group means are not matched

# %%
a.analyze([df['BODYFAT'].groupby(df['Class']).get_group('Normal'),
          df['BODYFAT'].groupby(df['Class']).get_group('Overweight')], groups=['Normal', 'Overweight'])
# Out:
# Group Statistics
#
# Count         Mean          Std Dev       Min           Median        Max           Group
# --------------------------------------------------------------------------------------------------
# 102            22.1098       5.3771        8.5000        21.8000       36.5000      Overweight
# 124            14.3089       6.0051        1.9000        13.5500       28.4000      Normal
#
#
# Mann Whitney U Test
# -------------------
#
# u value =  2197.5000
# p value =  0.0000
#
# HA: Locations are not matched

# %%
a.analyze([df['HEIGHT'].groupby(df['Class']).get_group('Normal'),
          df['HEIGHT'].groupby(df['Class']).get_group('Overweight')], groups=['Normal', 'Overweight'])
# Out:
# Group Statistics
#
# Count         Mean          Std Dev       Min           Median        Max           Group
# --------------------------------------------------------------------------------------------------
# 102            70.6201       2.6608        65.5000       70.0000       77.7500      Overweight
# 124            70.1593       2.5428        64.0000       70.2500       77.5000      Normal
#
#
# T Test
# ------
#
# t value = -1.3276
# p value =  0.1857
#
# H0: Means are matched
